# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os
from datetime import datetime
from dateutil.parser import parse
from api_keys import api_key
from citipy import citipy
output_data_file = "output_data/cities.csv"
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 620

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
cities = cities
url = "http://api.openweathermap.org/data/2.5/weather?"
city = 'Toronto'
uom = 'metric'
citiestest = ['Seoul','Beijing','New York','Tianjin']
cityList = pd.DataFrame(cities, columns=['City'])
params = {
    'units': uom
    ,'appid': api_key
    ,'q': city
    }

# %%
#cityList
cityList.to_csv(r'cityList.csv')

# %%
city_df = pd.read_csv('cityList.csv',index_col=[0])

# %%
lengthofrow = len(city_df)

# %%
weather = requests.get(url,params).json()
weather
# Out:
# {'coord': {'lon': -79.39, 'lat': 43.65},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 0.17,
#   'feels_like': -3.57,
#   'temp_min': -1.11,
#   'temp_max': 1.67,
#   'pressure': 1011,
#   'humidity': 64},
#  'visibility': 14484,
#  'wind': {'speed': 1.5, 'deg': 250},
#  'clouds': {'all': 90},
#  'dt': 1576618531,
#  'sys': {'type': 1,
#   'id': 941,
#   'country': 'CA',
#   'sunrise': 1576586728,
#   'sunset': 1576618908},
#  'timezone': -18000,
#  'id': 6167865,
#  'name': 'Toronto',
#  'cod': 200}

# %%
#cityTest = 'zavodoukovsk'
#query_url = url+'appid='+api_key+"&q="+cityTest+"&units=metric"
#weather = requests.get(query_url).json()
#weather
#country -------- weather['sys']['country']
#date ------------weather['dt']
#humidity --------weather['main']['humidity']
#longitude -------weather['coord']['lon']
#latitude --------weather['coord']['lat']
#max_temp --------weather['main']['temp_max']
#wind_speed ------weather['wind']['speed']

# %%
city_df['Cloudiness'] = ''
city_df['Country'] = ''
city_df['Date'] = ''
city_df['Humidity'] = ''
city_df['Latitude'] = ''

city_df['Longitude'] = ''
city_df['Max Temp'] = ''
city_df['Wind Speed'] = ''

# %%
city_df.head()
# Out:
#            City Cloudiness Country Date Humidity Latitude Longitude Max Temp  \
# 0         kieta
# 1   tuktoyaktuk
# 2  punta arenas
# 3   alta gracia
# 4      bengkulu
#
#   Wind Speed
# 0
# 1
# 2
# 3
# 4

# %%
#date ------------response['dt']
#humidity --------response['main']['humidity']
#longitude -------response['coord']['lon']
#latitude --------response['coord']['lat']
#max_temp --------response['main']['temp_max']
#wind_speed ------response['wind']['speed']
for index, row in city_df.iterrows():
    city = row['City']
    
    params = {
    'units': uom
    ,'appid': api_key
    ,'q': city
    }
    print(f'Processing Record {index} set of {lengthofrow} | {city}')
    response = requests.get(url,params=params).json()
    try:
        city_df.loc[index,'Cloudiness']=response['clouds']['all']
        city_df.loc[index,'Country']=response['sys']['country']
        city_df.loc[index,'Date']=response['dt']
        city_df.loc[index,'Humidity']=response['main']['humidity']
        city_df.loc[index,'Longitude']=response['coord']['lon']
        city_df.loc[index,'Latitude']=response['coord']['lat']
        city_df.loc[index,'Max Temp']=response['main']['temp_max']
        city_df.loc[index,'Wind Speed']=response['wind']['speed']
    except KeyError:
        print('missing values, i am going to skip it')
        print('====================================')
# Out:
# Processing Record 0 set of 620 | kieta
# Processing Record 1 set of 620 | tuktoyaktuk
# Processing Record 2 set of 620 | punta arenas
# Processing Record 3 set of 620 | alta gracia
# Processing Record 4 set of 620 | bengkulu
# missing values, i am going to skip it
# ====================================
# Processing Record 5 set of 620 | albany
# Processing Record 6 set of 620 | butaritari
# Processing Record 7 set of 620 | owando
# Processing Record 8 set of 620 | launceston
# Processing Record 9 set of 620 | khatanga
# Processing Record 10 set of 620 | nabire
# Processing Record 11 set of 620 | mayumba
# Processing Record 12 set of 620 | ushuaia
# Processing Record 13 set of 620 | puerto ayora
# Processing Record 14 set of 620 | ancud
# Processing Record 15 set of 620 | rurrenabaque
# Processing Record 16 set of 620 | les ponts-de-ce
# Processing Record 17 set of 620 | nabari
# Processing Record 18 set of 620 | lagoa
# Processing Record 19 set of 620 | boone
# Processing Record 20 set of 620 | faanui
# Processing Record 21 set of 620 | port elizabeth
# Processing Record 22 set of 620 | mataura
# Processing Record 23 set of 620 | kalemie
# Processing Record 24 set of 620 | kapaa
# Processing Record 25 set of 620 | zhangye
# Processing Record 26 set of 620 | hirara
# Processing Record 27 set of 620 | margate
# Processing Record 28 set of 620 | kupang
# Processing Record 29 set of 620 | bredasdorp
# Processing Record 30 set of 620 | mandera
# Processing Record 31 set of 620 | rikitea
# Processing Record 32 set of 620 | cape town
# Processing Record 33 set of 620 | hunza
# missing values, i am going to skip it
# ====================================
# Processing Record 34 set of 620 | kharp
# Processing Record 35 set of 620 | zubtsov
# Processing Record 36 set of 620 | kruisfontein
# Processing Record 37 set of 620 | awjilah
# Processing Record 38 set of 620 | mys shmidta
# missing values, i am going to skip it
# ====================================
# Processing Record 39 set of 620 | talnakh
# Processing Record 40 set of 620 | atar
# Processing Record 41 set of 620 | haibowan
# missing values, i am going to skip it
# ====================================
# Processing Record 42 set of 620 | port hedland
# Processing Record 43 set of 620 | rabo de peixe
# Processing Record 44 set of 620 | avarua
# Processing Record 45 set of 620 | qaanaaq
# Processing Record 46 set of 620 | nanyang
# Processing Record 47 set of 620 | mar del plata
# Processing Record 48 set of 620 | mahebourg
# Processing Record 49 set of 620 | chuy
# Processing Record 50 set of 620 | atuona
# Processing Record 51 set of 620 | ewa beach
# Processing Record 52 set of 620 | te anau
# Processing Record 53 set of 620 | chulym
# Processing Record 54 set of 620 | fort walton beach
# Processing Record 55 set of 620 | alofi
# Processing Record 56 set of 620 | vaitupu
# missing values, i am going to skip it
# ====================================
# Processing Record 57 set of 620 | yermolayevo
# Processing Record 58 set of 620 | hithadhoo
# Processing Record 59 set of 620 | carnarvon
# Processing Record 60 set of 620 | hobart
# Processing Record 61 set of 620 | hilo
# Processing Record 62 set of 620 | north branch
# Processing Record 63 set of 620 | grindavik
# Processing Record 64 set of 620 | taolanaro
# missing values, i am going to skip it
# ====================================
# Processing Record 65 set of 620 | dikson
# Processing Record 66 set of 620 | husavik
# Processing Record 67 set of 620 | sakakah
# missing values, i am going to skip it
# ====================================
# Processing Record 68 set of 620 | georgetown
# Processing Record 69 set of 620 | barentsburg
# missing values, i am going to skip it
# ====================================
# Processing Record 70 set of 620 | nyaunglebin
# Processing Record 71 set of 620 | omsukchan
# Processing Record 72 set of 620 | chokurdakh
# Processing Record 73 set of 620 | faya
# Processing Record 74 set of 620 | singleton
# Processing Record 75 set of 620 | seymchan
# Processing Record 76 set of 620 | barrow
# Processing Record 77 set of 620 | havelock
# Processing Record 78 set of 620 | yumen
# Processing Record 79 set of 620 | isangel
# Processing Record 80 set of 620 | saleaula
# missing values, i am going to skip it
# ====================================
# Processing Record 81 set of 620 | cabo san lucas
# Processing Record 82 set of 620 | illoqqortoormiut
# missing values, i am going to skip it
# ====================================
# Processing Record 83 set of 620 | thompson
# Processing Record 84 set of 620 | vaini
# Processing Record 85 set of 620 | chaochou
# missing values, i am going to skip it
# ====================================
# Processing Record 86 set of 620 | saint-francois
# Processing Record 87 set of 620 | geraldton
# Processing Record 88 set of 620 | new norfolk
# Processing Record 89 set of 620 | ribeira grande
# Processing Record 90 set of 620 | shimoda
# Processing Record 91 set of 620 | trairi
# Processing Record 92 set of 620 | bon air
# Processing Record 93 set of 620 | provideniya
# Processing Record 94 set of 620 | aden
# Processing Record 95 set of 620 | avera
# Processing Record 96 set of 620 | dicabisagan
# Processing Record 97 set of 620 | havoysund
# Processing Record 98 set of 620 | bamiantong
# Processing Record 99 set of 620 | yar-sale
# Processing Record 100 set of 620 | aksu
# Processing Record 101 set of 620 | saint george
# Processing Record 102 set of 620 | tiksi
# Processing Record 103 set of 620 | itarema
# Processing Record 104 set of 620 | bagn
# Processing Record 105 set of 620 | coquimbo
# Processing Record 106 set of 620 | norman wells
# Processing Record 107 set of 620 | tidore
# missing values, i am going to skip it
# ====================================
# Processing Record 108 set of 620 | sinnamary
# Processing Record 109 set of 620 | busselton
# Processing Record 110 set of 620 | boden
# Processing Record 111 set of 620 | asfi
# missing values, i am going to skip it
# ====================================
# Processing Record 112 set of 620 | mount isa
# Processing Record 113 set of 620 | nioro
# Processing Record 114 set of 620 | vanavara
# Processing Record 115 set of 620 | pangnirtung
# Processing Record 116 set of 620 | okakarara
# Processing Record 117 set of 620 | henties bay
# Processing Record 118 set of 620 | gualaquiza
# Processing Record 119 set of 620 | auki
# Processing Record 120 set of 620 | crab hill
# missing values, i am going to skip it
# ====================================
# Processing Record 121 set of 620 | esperance
# Processing Record 122 set of 620 | hermanus
# Processing Record 123 set of 620 | hasaki
# Processing Record 124 set of 620 | vestmannaeyjar
# Processing Record 125 set of 620 | muros
# Processing Record 126 set of 620 | urengoy
# Processing Record 127 set of 620 | porto novo
# Processing Record 128 set of 620 | sentyabrskiy
# missing values, i am going to skip it
# ====================================
# Processing Record 129 set of 620 | cayenne
# Processing Record 130 set of 620 | kavieng
# Processing Record 131 set of 620 | axim
# Processing Record 132 set of 620 | vila velha
# Processing Record 133 set of 620 | gatton
# Processing Record 134 set of 620 | lara
# Processing Record 135 set of 620 | okha
# Processing Record 136 set of 620 | port alfred
# Processing Record 137 set of 620 | sao filipe
# Processing Record 138 set of 620 | taonan
# Processing Record 139 set of 620 | hambantota
# Processing Record 140 set of 620 | atambua
# Processing Record 141 set of 620 | raudeberg
# Processing Record 142 set of 620 | souillac
# Processing Record 143 set of 620 | sibolga
# Processing Record 144 set of 620 | ostrovnoy
# Processing Record 145 set of 620 | salalah
# Processing Record 146 set of 620 | kamaishi
# Processing Record 147 set of 620 | mus
# Processing Record 148 set of 620 | fort frances
# Processing Record 149 set of 620 | bambous virieux
# Processing Record 150 set of 620 | longyearbyen
# Processing Record 151 set of 620 | sorland
# Processing Record 152 set of 620 | haradok
# Processing Record 153 set of 620 | jhinjhak
# Processing Record 154 set of 620 | kununurra
# Processing Record 155 set of 620 | jamestown
# Processing Record 156 set of 620 | high level
# Processing Record 157 set of 620 | male
# Processing Record 158 set of 620 | mehamn
# Processing Record 159 set of 620 | uxbridge
# Processing Record 160 set of 620 | nchelenge
# Processing Record 161 set of 620 | belmonte
# Processing Record 162 set of 620 | concordia
# Processing Record 163 set of 620 | upernavik
# Processing Record 164 set of 620 | samarai
# Processing Record 165 set of 620 | sitka
# Processing Record 166 set of 620 | yanam
# Processing Record 167 set of 620 | carutapera
# Processing Record 168 set of 620 | kampot
# Processing Record 169 set of 620 | arraial do cabo
# Processing Record 170 set of 620 | codrington
# Processing Record 171 set of 620 | nome
# Processing Record 172 set of 620 | yellowknife
# Processing Record 173 set of 620 | ngorongoro
# Processing Record 174 set of 620 | motygino
# Processing Record 175 set of 620 | iquique
# Processing Record 176 set of 620 | matara
# Processing Record 177 set of 620 | tasiilaq
# Processing Record 178 set of 620 | petropavlovsk-kamchatskiy
# Processing Record 179 set of 620 | belushya guba
# missing values, i am going to skip it
# ====================================
# Processing Record 180 set of 620 | qaqortoq
# Processing Record 181 set of 620 | rawannawi
# missing values, i am going to skip it
# ====================================
# Processing Record 182 set of 620 | nikolskoye
# Processing Record 183 set of 620 | oksfjord
# Processing Record 184 set of 620 | pevek
# Processing Record 185 set of 620 | solnechnyy
# Processing Record 186 set of 620 | dasoguz
# Processing Record 187 set of 620 | whitecourt
# Processing Record 188 set of 620 | jadu
# Processing Record 189 set of 620 | egvekinot
# Processing Record 190 set of 620 | hornepayne
# Processing Record 191 set of 620 | hofn
# Processing Record 192 set of 620 | worthington
# Processing Record 193 set of 620 | la ronge
# Processing Record 194 set of 620 | sola
# Processing Record 195 set of 620 | deputatskiy
# Processing Record 196 set of 620 | pisco
# Processing Record 197 set of 620 | airai
# Processing Record 198 set of 620 | mecca
# Processing Record 199 set of 620 | irbil
# missing values, i am going to skip it
# ====================================
# Processing Record 200 set of 620 | portland
# Processing Record 201 set of 620 | surubim
# Processing Record 202 set of 620 | christchurch
# Processing Record 203 set of 620 | lata
# Processing Record 204 set of 620 | iqaluit
# Processing Record 205 set of 620 | korhogo
# Processing Record 206 set of 620 | lebu
# Processing Record 207 set of 620 | fairbanks
# Processing Record 208 set of 620 | srandakan
# Processing Record 209 set of 620 | emba
# Processing Record 210 set of 620 | lavrentiya
# Processing Record 211 set of 620 | nova vodolaha
# Processing Record 212 set of 620 | toro
# Processing Record 213 set of 620 | nanortalik
# Processing Record 214 set of 620 | san angelo
# Processing Record 215 set of 620 | boulsa
# Processing Record 216 set of 620 | muscat
# Processing Record 217 set of 620 | bluff
# Processing Record 218 set of 620 | marcona
# missing values, i am going to skip it
# ====================================
# Processing Record 219 set of 620 | malwan
# missing values, i am going to skip it
# ====================================
# Processing Record 220 set of 620 | cidreira
# Processing Record 221 set of 620 | ponta do sol
# Processing Record 222 set of 620 | dingle
# Processing Record 223 set of 620 | castro
# Processing Record 224 set of 620 | mogadishu
# Processing Record 225 set of 620 | timizart
# Processing Record 226 set of 620 | san patricio
# Processing Record 227 set of 620 | birjand
# Processing Record 228 set of 620 | leshukonskoye
# Processing Record 229 set of 620 | beira
# Processing Record 230 set of 620 | nebolchi
# Processing Record 231 set of 620 | batticaloa
# Processing Record 232 set of 620 | nizhneyansk
# missing values, i am going to skip it
# ====================================
# Processing Record 233 set of 620 | kropotkin
# Processing Record 234 set of 620 | madhupur
# Processing Record 235 set of 620 | caucaia
# Processing Record 236 set of 620 | fiumicino
# Processing Record 237 set of 620 | narsaq
# Processing Record 238 set of 620 | vila franca do campo
# Processing Record 239 set of 620 | hobyo
# Processing Record 240 set of 620 | palauig
# Processing Record 241 set of 620 | san carlos de bariloche
# Processing Record 242 set of 620 | laguna
# Processing Record 243 set of 620 | asifabad
# Processing Record 244 set of 620 | sao joao da barra
# Processing Record 245 set of 620 | fort-shevchenko
# Processing Record 246 set of 620 | douglas
# Processing Record 247 set of 620 | saint-philippe
# Processing Record 248 set of 620 | buchanan
# Processing Record 249 set of 620 | krasnoselkup
# missing values, i am going to skip it
# ====================================
# Processing Record 250 set of 620 | zhezkazgan
# Processing Record 251 set of 620 | eydhafushi
# Processing Record 252 set of 620 | cherskiy
# Processing Record 253 set of 620 | ilulissat
# Processing Record 254 set of 620 | ronneby
# Processing Record 255 set of 620 | dudinka
# Processing Record 256 set of 620 | sibu
# Processing Record 257 set of 620 | meyungs
# missing values, i am going to skip it
# ====================================
# Processing Record 258 set of 620 | novikovo
# Processing Record 259 set of 620 | rybachiy
# Processing Record 260 set of 620 | zalantun
# Processing Record 261 set of 620 | lufilufi
# Processing Record 262 set of 620 | lompoc
# Processing Record 263 set of 620 | touros
# Processing Record 264 set of 620 | labuhan
# Processing Record 265 set of 620 | umm kaddadah
# Processing Record 266 set of 620 | bethel
# Processing Record 267 set of 620 | canela
# Processing Record 268 set of 620 | ahipara
# Processing Record 269 set of 620 | yirol
# missing values, i am going to skip it
# ====================================
# Processing Record 270 set of 620 | miles city
# Processing Record 271 set of 620 | connersville
# Processing Record 272 set of 620 | hovd
# Processing Record 273 set of 620 | klaksvik
# Processing Record 274 set of 620 | hamilton
# Processing Record 275 set of 620 | zhanatas
# missing values, i am going to skip it
# ====================================
# Processing Record 276 set of 620 | khotyn
# Processing Record 277 set of 620 | sosnovo-ozerskoye
# Processing Record 278 set of 620 | saldanha
# Processing Record 279 set of 620 | alice springs
# Processing Record 280 set of 620 | yulara
# Processing Record 281 set of 620 | kodiak
# Processing Record 282 set of 620 | skibotn
# Processing Record 283 set of 620 | bouillante
# Processing Record 284 set of 620 | bahia blanca
# Processing Record 285 set of 620 | chodavaram
# Processing Record 286 set of 620 | hay river
# Processing Record 287 set of 620 | charlestown
# Processing Record 288 set of 620 | weligama
# Processing Record 289 set of 620 | namatanai
# Processing Record 290 set of 620 | veraval
# Processing Record 291 set of 620 | lhokseumawe
# Processing Record 292 set of 620 | saint-georges
# Processing Record 293 set of 620 | puerto madryn
# Processing Record 294 set of 620 | freeport
# Processing Record 295 set of 620 | isla vista
# Processing Record 296 set of 620 | constitucion
# Processing Record 297 set of 620 | poum
# Processing Record 298 set of 620 | chumikan
# Processing Record 299 set of 620 | ulladulla
# Processing Record 300 set of 620 | jining
# Processing Record 301 set of 620 | palapye
# Processing Record 302 set of 620 | volchikha
# Processing Record 303 set of 620 | cerro azul
# Processing Record 304 set of 620 | prince rupert
# Processing Record 305 set of 620 | saint anthony
# Processing Record 306 set of 620 | havre-saint-pierre
# Processing Record 307 set of 620 | onda
# Processing Record 308 set of 620 | saskylakh
# Processing Record 309 set of 620 | denpasar
# Processing Record 310 set of 620 | changping
# Processing Record 311 set of 620 | barcelos
# Processing Record 312 set of 620 | mount gambier
# Processing Record 313 set of 620 | chongwe
# Processing Record 314 set of 620 | meiganga
# Processing Record 315 set of 620 | tobermory
# Processing Record 316 set of 620 | goderich
# Processing Record 317 set of 620 | dubti
# Processing Record 318 set of 620 | santa cruz de la palma
# Processing Record 319 set of 620 | dwarka
# Processing Record 320 set of 620 | felidhoo
# missing values, i am going to skip it
# ====================================
# Processing Record 321 set of 620 | thinadhoo
# Processing Record 322 set of 620 | duldurga
# Processing Record 323 set of 620 | phan rang
# missing values, i am going to skip it
# ====================================
# Processing Record 324 set of 620 | lianzhou
# Processing Record 325 set of 620 | hammerfest
# Processing Record 326 set of 620 | ust-kamchatsk
# missing values, i am going to skip it
# ====================================
# Processing Record 327 set of 620 | carballo
# Processing Record 328 set of 620 | tessalit
# Processing Record 329 set of 620 | moron
# Processing Record 330 set of 620 | mattru
# Processing Record 331 set of 620 | yangjiang
# Processing Record 332 set of 620 | grand gaube
# Processing Record 333 set of 620 | pirgos
# Processing Record 334 set of 620 | halifax
# Processing Record 335 set of 620 | taburi
# missing values, i am going to skip it
# ====================================
# Processing Record 336 set of 620 | rudnogorsk
# Processing Record 337 set of 620 | artyk
# missing values, i am going to skip it
# ====================================
# Processing Record 338 set of 620 | hami
# Processing Record 339 set of 620 | benalla
# Processing Record 340 set of 620 | kiunga
# Processing Record 341 set of 620 | agirish
# Processing Record 342 set of 620 | gamba
# Processing Record 343 set of 620 | los llanos de aridane
# Processing Record 344 set of 620 | tuy hoa
# Processing Record 345 set of 620 | tabiauea
# missing values, i am going to skip it
# ====================================
# Processing Record 346 set of 620 | puerto leguizamo
# Processing Record 347 set of 620 | san cristobal
# Processing Record 348 set of 620 | tumannyy
# missing values, i am going to skip it
# ====================================
# Processing Record 349 set of 620 | kpandae
# Processing Record 350 set of 620 | camacha
# Processing Record 351 set of 620 | winslow
# Processing Record 352 set of 620 | amberley
# Processing Record 353 set of 620 | kathmandu
# Processing Record 354 set of 620 | sumenep
# Processing Record 355 set of 620 | alibag
# Processing Record 356 set of 620 | clyde river
# Processing Record 357 set of 620 | santa eulalia del rio
# missing values, i am going to skip it
# ====================================
# Processing Record 358 set of 620 | batsfjord
# Processing Record 359 set of 620 | broome
# Processing Record 360 set of 620 | milledgeville
# Processing Record 361 set of 620 | saint-augustin
# Processing Record 362 set of 620 | huangchuan
# Processing Record 363 set of 620 | kaduna
# Processing Record 364 set of 620 | gizo
# Processing Record 365 set of 620 | cyangugu
# Processing Record 366 set of 620 | oxapampa
# Processing Record 367 set of 620 | sikonge
# Processing Record 368 set of 620 | tendukheda
# Processing Record 369 set of 620 | vrangel
# Processing Record 370 set of 620 | port lincoln
# Processing Record 371 set of 620 | namibe
# Processing Record 372 set of 620 | raha
# Processing Record 373 set of 620 | kaeo
# Processing Record 374 set of 620 | gorodovikovsk
# Processing Record 375 set of 620 | fortuna
# Processing Record 376 set of 620 | east london
# Processing Record 377 set of 620 | shima
# Processing Record 378 set of 620 | barra do corda
# Processing Record 379 set of 620 | pangody
# Processing Record 380 set of 620 | waingapu
# Processing Record 381 set of 620 | bargal
# missing values, i am going to skip it
# ====================================
# Processing Record 382 set of 620 | ambodifototra
# missing values, i am going to skip it
# ====================================
# Processing Record 383 set of 620 | praia da vitoria
# Processing Record 384 set of 620 | xining
# Processing Record 385 set of 620 | severo-kurilsk
# Processing Record 386 set of 620 | kirkuk
# Processing Record 387 set of 620 | morant bay
# Processing Record 388 set of 620 | zhigansk
# Processing Record 389 set of 620 | bolgatanga
# Processing Record 390 set of 620 | victor harbor
# Processing Record 391 set of 620 | aklavik
# Processing Record 392 set of 620 | sao jose da coroa grande
# Processing Record 393 set of 620 | gat
# Processing Record 394 set of 620 | trebisacce
# Processing Record 395 set of 620 | bat khela
# Processing Record 396 set of 620 | akureyri
# Processing Record 397 set of 620 | eqbaliyeh
# Processing Record 398 set of 620 | vao
# Processing Record 399 set of 620 | yuzhno-yeniseyskiy
# missing values, i am going to skip it
# ====================================
# Processing Record 400 set of 620 | antalaha
# Processing Record 401 set of 620 | evensk
# Processing Record 402 set of 620 | hailin
# Processing Record 403 set of 620 | malindi
# Processing Record 404 set of 620 | burns lake
# Processing Record 405 set of 620 | todos santos
# Processing Record 406 set of 620 | bistret
# missing values, i am going to skip it
# ====================================
# Processing Record 407 set of 620 | naron
# Processing Record 408 set of 620 | college
# Processing Record 409 set of 620 | sulangan
# Processing Record 410 set of 620 | vostok
# Processing Record 411 set of 620 | chicama
# Processing Record 412 set of 620 | goundam
# Processing Record 413 set of 620 | pervomayskoye
# Processing Record 414 set of 620 | kaka
# Processing Record 415 set of 620 | verkhnevilyuysk
# Processing Record 416 set of 620 | hede
# Processing Record 417 set of 620 | kaitangata
# Processing Record 418 set of 620 | saint-louis
# Processing Record 419 set of 620 | baiyin
# Processing Record 420 set of 620 | skibbereen
# Processing Record 421 set of 620 | strezhevoy
# Processing Record 422 set of 620 | honiara
# Processing Record 423 set of 620 | gizel
# Processing Record 424 set of 620 | coihueco
# Processing Record 425 set of 620 | celestun
# Processing Record 426 set of 620 | hanmer springs
# Processing Record 427 set of 620 | hanzhong
# Processing Record 428 set of 620 | comodoro rivadavia
# Processing Record 429 set of 620 | kihei
# Processing Record 430 set of 620 | neryungri
# Processing Record 431 set of 620 | broken hill
# Processing Record 432 set of 620 | nguiu
# missing values, i am going to skip it
# ====================================
# Processing Record 433 set of 620 | muravlenko
# Processing Record 434 set of 620 | iracoubo
# Processing Record 435 set of 620 | raga
# missing values, i am going to skip it
# ====================================
# Processing Record 436 set of 620 | torbay
# Processing Record 437 set of 620 | rafraf
# Processing Record 438 set of 620 | matagami
# Processing Record 439 set of 620 | sedelnikovo
# missing values, i am going to skip it
# ====================================
# Processing Record 440 set of 620 | barabai
# Processing Record 441 set of 620 | pathein
# Processing Record 442 set of 620 | toledo
# Processing Record 443 set of 620 | macamic
# Processing Record 444 set of 620 | utiroa
# missing values, i am going to skip it
# ====================================
# Processing Record 445 set of 620 | redmond
# Processing Record 446 set of 620 | port macquarie
# Processing Record 447 set of 620 | la romana
# Processing Record 448 set of 620 | yerbogachen
# Processing Record 449 set of 620 | grand river south east
# missing values, i am going to skip it
# ====================================
# Processing Record 450 set of 620 | farah
# Processing Record 451 set of 620 | luderitz
# Processing Record 452 set of 620 | iskateley
# Processing Record 453 set of 620 | victoria
# Processing Record 454 set of 620 | oistins
# Processing Record 455 set of 620 | karachi
# Processing Record 456 set of 620 | salekhard
# Processing Record 457 set of 620 | san jeronimo
# Processing Record 458 set of 620 | bud
# Processing Record 459 set of 620 | pedernales
# Processing Record 460 set of 620 | rawson
# Processing Record 461 set of 620 | pacific grove
# Processing Record 462 set of 620 | solsvik
# missing values, i am going to skip it
# ====================================
# Processing Record 463 set of 620 | zvishavane
# Processing Record 464 set of 620 | osmena
# Processing Record 465 set of 620 | mackenzie
# Processing Record 466 set of 620 | kijang
# Processing Record 467 set of 620 | aksay
# Processing Record 468 set of 620 | sur
# Processing Record 469 set of 620 | lolua
# missing values, i am going to skip it
# ====================================
# Processing Record 470 set of 620 | dongling
# Processing Record 471 set of 620 | flinders
# Processing Record 472 set of 620 | cap malheureux
# Processing Record 473 set of 620 | cotonou
# Processing Record 474 set of 620 | taltal
# Processing Record 475 set of 620 | pietersburg
# missing values, i am going to skip it
# ====================================
# Processing Record 476 set of 620 | virginia beach
# Processing Record 477 set of 620 | berzasca
# Processing Record 478 set of 620 | phatthalung
# Processing Record 479 set of 620 | haines junction
# Processing Record 480 set of 620 | arman
# Processing Record 481 set of 620 | xuddur
# Processing Record 482 set of 620 | barbosa ferraz
# Processing Record 483 set of 620 | changji
# Processing Record 484 set of 620 | tir pol
# missing values, i am going to skip it
# ====================================
# Processing Record 485 set of 620 | buenos aires
# Processing Record 486 set of 620 | liverpool
# Processing Record 487 set of 620 | zyryanka
# Processing Record 488 set of 620 | petropavl
# Processing Record 489 set of 620 | louisbourg
# missing values, i am going to skip it
# ====================================
# Processing Record 490 set of 620 | sembakung
# Processing Record 491 set of 620 | chute-aux-outardes
# Processing Record 492 set of 620 | paamiut
# Processing Record 493 set of 620 | sinop
# Processing Record 494 set of 620 | naze
# Processing Record 495 set of 620 | chagda
# missing values, i am going to skip it
# ====================================
# Processing Record 496 set of 620 | neuquen
# Processing Record 497 set of 620 | ovre ardal
# Processing Record 498 set of 620 | vallenar
# Processing Record 499 set of 620 | khasan
# Processing Record 500 set of 620 | anchorage
# Processing Record 501 set of 620 | inirida
# Processing Record 502 set of 620 | batemans bay
# Processing Record 503 set of 620 | samusu
# missing values, i am going to skip it
# ====================================
# Processing Record 504 set of 620 | chyhyryn
# Processing Record 505 set of 620 | churapcha
# Processing Record 506 set of 620 | pitimbu
# Processing Record 507 set of 620 | amderma
# missing values, i am going to skip it
# ====================================
# Processing Record 508 set of 620 | iranshahr
# Processing Record 509 set of 620 | zhanakorgan
# Processing Record 510 set of 620 | kasongo-lunda
# Processing Record 511 set of 620 | viedma
# Processing Record 512 set of 620 | gondar
# Processing Record 513 set of 620 | morgan city
# Processing Record 514 set of 620 | mabaruma
# Processing Record 515 set of 620 | mnogovershinnyy
# Processing Record 516 set of 620 | jackson
# Processing Record 517 set of 620 | san ramon
# Processing Record 518 set of 620 | ambon
# Processing Record 519 set of 620 | cap-aux-meules
# Processing Record 520 set of 620 | kahului
# Processing Record 521 set of 620 | roscommon
# Processing Record 522 set of 620 | elk city
# Processing Record 523 set of 620 | kudahuvadhoo
# Processing Record 524 set of 620 | maningrida
# Processing Record 525 set of 620 | ouesso
# Processing Record 526 set of 620 | ventersburg
# Processing Record 527 set of 620 | saint-joseph
# Processing Record 528 set of 620 | prado
# Processing Record 529 set of 620 | rio grande
# Processing Record 530 set of 620 | sorvag
# missing values, i am going to skip it
# ====================================
# Processing Record 531 set of 620 | eureka
# Processing Record 532 set of 620 | kentville
# Processing Record 533 set of 620 | rocky mountain house
# Processing Record 534 set of 620 | sorong
# Processing Record 535 set of 620 | aitape
# Processing Record 536 set of 620 | galgani
# missing values, i am going to skip it
# ====================================
# Processing Record 537 set of 620 | joshimath
# Processing Record 538 set of 620 | sambava
# Processing Record 539 set of 620 | holt
# Processing Record 540 set of 620 | doha
# Processing Record 541 set of 620 | mukhen
# Processing Record 542 set of 620 | stege
# Processing Record 543 set of 620 | troitskoye
# Processing Record 544 set of 620 | cervo
# Processing Record 545 set of 620 | la crosse
# Processing Record 546 set of 620 | olafsvik
# missing values, i am going to skip it
# ====================================
# Processing Record 547 set of 620 | champerico
# Processing Record 548 set of 620 | ojinaga
# Processing Record 549 set of 620 | sobolevo
# Processing Record 550 set of 620 | general roca
# Processing Record 551 set of 620 | port augusta
# Processing Record 552 set of 620 | baiao
# Processing Record 553 set of 620 | great falls
# Processing Record 554 set of 620 | attawapiskat
# missing values, i am going to skip it
# ====================================
# Processing Record 555 set of 620 | nishihara
# Processing Record 556 set of 620 | hope
# Processing Record 557 set of 620 | dauphin
# Processing Record 558 set of 620 | darhan
# Processing Record 559 set of 620 | kungurtug
# Processing Record 560 set of 620 | tarlisua
# missing values, i am going to skip it
# ====================================
# Processing Record 561 set of 620 | oktyabrskoye
# Processing Record 562 set of 620 | pointe michel
# Processing Record 563 set of 620 | leningradskiy
# Processing Record 564 set of 620 | nagykanizsa
# Processing Record 565 set of 620 | misratah
# Processing Record 566 set of 620 | karla
# Processing Record 567 set of 620 | inuvik
# Processing Record 568 set of 620 | dortyol
# Processing Record 569 set of 620 | bonavista
# Processing Record 570 set of 620 | berezovka
# Processing Record 571 set of 620 | norfolk
# Processing Record 572 set of 620 | payakumbuh
# Processing Record 573 set of 620 | vidim
# Processing Record 574 set of 620 | alekseyevsk
# Processing Record 575 set of 620 | tinskoy
# Processing Record 576 set of 620 | howard springs
# Processing Record 577 set of 620 | kamenskoye
# missing values, i am going to skip it
# ====================================
# Processing Record 578 set of 620 | guerrero negro
# Processing Record 579 set of 620 | kamenjane
# Processing Record 580 set of 620 | kokopo
# Processing Record 581 set of 620 | markova
# Processing Record 582 set of 620 | odemira
# Processing Record 583 set of 620 | karaul
# missing values, i am going to skip it
# ====================================
# Processing Record 584 set of 620 | ayagoz
# Processing Record 585 set of 620 | kerema
# Processing Record 586 set of 620 | guatire
# Processing Record 587 set of 620 | zambezi
# Processing Record 588 set of 620 | sao borja
# Processing Record 589 set of 620 | whitehorse
# Processing Record 590 set of 620 | karauzyak
# missing values, i am going to skip it
# ====================================
# Processing Record 591 set of 620 | thunder bay
# Processing Record 592 set of 620 | awbari
# Processing Record 593 set of 620 | marystown
# Processing Record 594 set of 620 | kisangani
# Processing Record 595 set of 620 | hualmay
# Processing Record 596 set of 620 | maniitsoq
# Processing Record 597 set of 620 | ulverstone
# Processing Record 598 set of 620 | borogontsy
# Processing Record 599 set of 620 | tamsweg
# Processing Record 600 set of 620 | casablanca
# Processing Record 601 set of 620 | tsihombe
# missing values, i am going to skip it
# ====================================
# Processing Record 602 set of 620 | mingguang
# Processing Record 603 set of 620 | sungaipenuh
# Processing Record 604 set of 620 | altoona
# Processing Record 605 set of 620 | marawi
# Processing Record 606 set of 620 | lodwar
# Processing Record 607 set of 620 | erenhot
# Processing Record 608 set of 620 | changuinola
# Processing Record 609 set of 620 | sarangani
# Processing Record 610 set of 620 | pomichna
# Processing Record 611 set of 620 | pagudpud
# Processing Record 612 set of 620 | nara
# Processing Record 613 set of 620 | kargasok
# Processing Record 614 set of 620 | shelburne
# Processing Record 615 set of 620 | chimbote
# Processing Record 616 set of 620 | tual
# Processing Record 617 set of 620 | boa vista
# Processing Record 618 set of 620 | parry sound
# Processing Record 619 set of 620 | panzhihua

# %%
city_df.head()
# Out:
#            City Cloudiness Country        Date Humidity Latitude Longitude  \
# 0         kieta         28      PG  1576618839       78    -6.22    155.63
# 1   tuktoyaktuk         20      CA  1576618839       74    69.44   -133.03
# 2  punta arenas         75      CL  1576618839       67   -53.16    -70.91
# 3   alta gracia          0      AR  1576618839       15   -31.66    -64.43
# 4      bengkulu
#
#   Max Temp Wind Speed
# 0    26.68       2.26
# 1      -33        1.5
# 2       14        5.7
# 3    33.33        8.2
# 4

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_df.to_csv(r'city_df.csv')

# %%
citydf = pd.read_csv('city_df.csv',index_col=[0])

# %%
citydf.count()
# Out:
# City          620
# Cloudiness    561
# Country       558
# Date          561
# Humidity      561
# Latitude      561
# Longitude     561
# Max Temp      561
# Wind Speed    561
# dtype: int64

# %%
citydf =citydf.dropna(how='any')

# %%
citydf =citydf.reset_index(drop=True)

# %%
citydf.count()
# Out:
# City          558
# Cloudiness    558
# Country       558
# Date          558
# Humidity      558
# Latitude      558
# Longitude     558
# Max Temp      558
# Wind Speed    558
# dtype: int64

# %%
def windspeeds(x):
    '''convert MPS Wind Speed to miles per hour'''
    return x * 2.236936

# %%
for x in citydf['Wind Speed']:
    citydf['Wind Speed (mph)'] = windspeeds(citydf['Wind Speed'])

# %%
def Farenheit(i):
    '''convert Kevlin to Farenheit'''
    return (i-273.15) * 9/5 + 32

# %%
for x in citydf['Max Temp']:
    citydf['Max Temp (F)'] = Farenheit(citydf['Max Temp'])

# %%
citydf.head()
# Out:
#            City  Cloudiness Country          Date  Humidity  Latitude  \
# 0         kieta        28.0      PG  1.576619e+09      78.0     -6.22
# 1   tuktoyaktuk        20.0      CA  1.576619e+09      74.0     69.44
# 2  punta arenas        75.0      CL  1.576619e+09      67.0    -53.16
# 3   alta gracia         0.0      AR  1.576619e+09      15.0    -31.66
# 4        albany        90.0      US  1.576619e+09      92.0     42.65
#
#    Longitude  Max Temp  Wind Speed  Wind Speed (mph)  Max Temp (F)
# 0     155.63     26.68        2.26          5.055475      -411.646
# 1    -133.03    -33.00        1.50          3.355404      -519.070
# 2     -70.91     14.00        5.70         12.750535      -434.470
# 3     -64.43     33.33        8.20         18.342875      -399.676
# 4     -73.75     -1.11        1.50          3.355404      -461.668

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
x_axis = citydf['Latitude']

# %%
y_axis = citydf['Max Temp']

# %%
date = pd.to_datetime(citydf['Date'][0],unit='s')
date = date.strftime('%m-%d-%y')
date = str(date)
date
#date = str(date)
#date = date[:10]
date = "(" + date + ")"
#date.strftime('%mm-%dd-%YY')

# %%
figure, ax = plt.subplots()
ax.scatter(x_axis,y_axis,c='red',alpha=0.5,edgecolor='black',s=400)
ax.grid(color='white')
ax.set_ylim(-40,60)
ax.set_title(f'City Latitude vs. Max Temperature {date}',size = 15.0)
ax.set_xlabel('Latitude',fontsize = 15.0)
ax.set_ylabel('Max Temperature (F)',fontsize = 15.0)
ax.set_facecolor('lightblue')
figure.set_figheight(15)
figure.set_figwidth(15)
ax.tick_params(axis='both', labelsize=15.0)

#plt.scatter(x_axis,y_axis,alpha=0.5,color='red',edgecolors='black',s=50)
#plt.ylim(-40,50)
#plt.title(f'City Latitude vs. Max Temperature {date}')
#plt.ylabel('Max Temperature (F)')
#plt.xlabel('Latitude')
#plt.grid()
plt.savefig(os.path.join(f'City Latitude vs Max Temperature.png'))
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
y_axis = citydf['Humidity']

# %%
figure, ax = plt.subplots()
ax.scatter(x_axis,y_axis,c='purple',alpha=0.6,edgecolor='black',s=400)
ax.grid(color='white')
ax.set_ylim(-2,110)
ax.set_title(f'City Latitude vs. Humidity {date}',size=15)
ax.set_xlabel('Latitude',fontsize=15)
ax.set_ylabel('Max Temperature (F)',fontsize=15)
ax.set_facecolor('lightblue')
figure.set_figheight(15)
figure.set_figwidth(15)
ax.tick_params(axis='both', labelsize=15.0)

#plt.scatter(x_axis,y_axis,alpha=0.7,c='lightblue',edgecolors='black')
#plt.ylim(0,105)
#plt.title(f'City Latitude vs. Humidity {date}')
#plt.ylabel('Humidity (%)')
#plt.xlabel('Latitude')
#plt.grid()
plt.savefig(os.path.join(f'City Latitude vs Humidity.png'))
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
y_axis = citydf['Cloudiness']

# %%
figure, ax = plt.subplots()
ax.scatter(x_axis,y_axis,c='gray',alpha=0.7,edgecolor='black',s=400)
ax.grid(color='white')
ax.set_ylim()
ax.set_title(f'City Latitude vs. Cloudiness {date}',size=15)
ax.set_xlabel('Latitude',fontsize=15)
ax.set_ylabel('Max Temperature (F)',fontsize=15)
ax.set_facecolor('lightblue')
figure.set_figheight(15)
figure.set_figwidth(15)
ax.tick_params(axis='both', labelsize=15.0)

#plt.scatter(x_axis,y_axis,alpha=0.6,c='purple',edgecolors='black')
#plt.title(f'City Latitude vs. Cloudiness {date}')
#plt.ylabel('Cloudiness (%)')
#plt.xlabel('Latitude')
#plt.grid()
plt.savefig(os.path.join(f'City Latitude vs Cloudiness.png'))
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
y_axis = citydf['Wind Speed (mph)']

# %%
figure, ax = plt.subplots()
ax.scatter(x_axis,y_axis,c='orange',alpha=0.5,edgecolor='black',s=400)
ax.grid(color='white')
ax.set_ylim()
ax.set_title(f'City Latitude vs. Max Wind Speed {date}',size=15)
ax.set_xlabel('Latitude',fontsize=15)
ax.set_ylabel('Max Temperature (F)',fontsize=15)
ax.set_facecolor('lightblue')
figure.set_figheight(15)
figure.set_figwidth(15)
ax.tick_params(axis='both', labelsize=15.0)

#plt.scatter(x_axis,y_axis,alpha=0.7,c='orange',edgecolors='black')
#plt.ylim(-5,50)
#plt.title(f'City Latitude vs. Wind Speed {date}')
#plt.ylabel('Wind Speed (mph)')
#plt.xlabel('Latitude')
#plt.grid()
plt.savefig(os.path.join(f'City Latitude vs Wind Speed.png'))
plt.show()
